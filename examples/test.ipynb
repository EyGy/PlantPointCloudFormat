# %% [markdown]
# ## Plant Point Cloud Format (PPF) example Notebook

# %%
import sys
sys.path.insert(0,"../src/")
#import ppf
from ppf import read_ppf, write_ppf, PPFPointCloud, LabelDefinition

# %%
full_example = read_ppf(filepath="full_ppf_example_begonia.ply")

# %%
write_ppf(full_example,"asdf.ppf")

# %%
full_example.get_label_by_id(0)

# %%
full_example.summary
# Out:
# <bound method PPFPointCloud.summary of PPFPointCloud(points=array([[ 0.01504 , -0.047061, -0.104305],
#        [-0.085588, -0.044405,  0.093633],
#        [-0.042303,  0.014323,  0.1128  ],
#        ...,
#        [-0.077045, -0.062208, -0.038517],
#        [-0.067867, -0.114156, -0.190644],
#        [ 0.189888,  0.011949,  0.107515]], dtype=float32), metadata={'ppf_version': '1.0', 'plant_id': 'ppf_example_begonia_maculata_001_t2', 'subject_id': 'begonia_maculata_001', 'timepoint_index': '2', 'species': 'Begonia maculata', 'acquisition_date': '2025-01-22', 'acquisition_time': '13:46:05Z', 'sensor_type': 'sfm', 'dataset_name': 'PPF_Example_Dataset', 'processing_level': 'cleaned'}, labels=[], semantic_id=array([2, 1, 1, ..., 1, 8, 1]), instance_id=array([0, 7, 6, ..., 3, 0, 9]), colors=array([[35, 34, 23],
#        [56, 53, 31],
#        [77, 78, 60],
#        ...,
#        [38, 36, 22],
#        [ 9,  9,  9],
# ...

# %%
full_example.metadata
# Out:
# {'ppf_version': '1.0',
#  'plant_id': 'ppf_example_begonia_maculata_001_t2',
#  'subject_id': 'begonia_maculata_001',
#  'timepoint_index': '2',
#  'species': 'Begonia maculata',
#  'acquisition_date': '2025-01-22',
#  'acquisition_time': '13:46:05Z',
#  'sensor_type': 'sfm',
#  'dataset_name': 'PPF_Example_Dataset',
#  'processing_level': 'cleaned'}
